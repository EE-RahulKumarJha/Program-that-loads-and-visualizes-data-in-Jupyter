# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('data/iris.csv')

# Calculate and plot the mean and standard deviation
mean = data.mean()
std = data.std()
plt.errorbar(x=mean.index, y=mean.values, yerr=std.values, fmt='o')

# Set the plot labels and title
plt.xlabel('Measurement')
plt.ylabel('Value')
plt.title('Mean and Standard Deviation')

# Show the plot
plt.show()
# Out:
# <ipython-input-3-9a2ff9f4ad74>:9: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean = data.mean()
# <ipython-input-3-9a2ff9f4ad74>:10: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std = data.std()
